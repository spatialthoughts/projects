# %% [markdown]
# # Converting Geonames TSV to GeoPackage

# %%
import os
import pandas as pd
import geopandas as gpd

# %%
filename = 'data/cities500.txt'

# %%
column_names = [
    'geonameid', 'name', 'asciiname', 'alternatenames', 
    'latitude', 'longitude', 'feature class', 'feature code',
    'country code', 'cc2', 'admin1 code', 'admin2 code',
    'admin3 code', 'admin4 code', 'population', 'elevation',
    'dem', 'timezone', 'modification date'
]

df = pd.read_csv(filename, sep='\t', names=column_names)
df
# Out:
# /Users/ujaval/opt/anaconda3/envs/python_foundation/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         geonameid                 name            asciiname  \
# 0         3038999               Soldeu               Soldeu
# 1         3039154            El Tarter            El Tarter
# 2         3039163  Sant Julià de Lòria  Sant Julia de Loria
# 3         3039604       Pas de la Casa       Pas de la Casa
# 4         3039678               Ordino               Ordino
# ...           ...                  ...                  ...
# 196476     895269           Beitbridge           Beitbridge
# 196477     895308             Beatrice             Beatrice
# 196478     895417               Banket               Banket
# 196479    1085510              Epworth              Epworth
# ...

# %%
geometry = gpd.points_from_xy(df.longitude, df.latitude)
gdf = gpd.GeoDataFrame(df, crs='EPSG:4326', geometry=geometry)
print(gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 196481 entries, 0 to 196480
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   geonameid          196481 non-null  int64
#  1   name               196481 non-null  object
#  2   asciiname          196464 non-null  object
#  3   alternatenames     161429 non-null  object
#  4   latitude           196481 non-null  float64
#  5   longitude          196481 non-null  float64
#  6   feature class      196481 non-null  object
#  7   feature code       196480 non-null  object
#  8   country code       196436 non-null  object
#  9   cc2                6379 non-null    object
#  10  admin1 code        196446 non-null  object
#  11  admin2 code        149897 non-null  object
#  12  admin3 code        88595 non-null   object
#  13  admin4 code        32443 non-null   object
#  14  population         196481 non-null  int64
# ...

# %%
output_dir = 'output'
output_filename = 'us_cities.gpkg'
output_path = os.path.join(output_dir, output_filename)

filtered = gdf[gdf['country code'] == 'US']
filtered.to_file(driver='GPKG', filename=output_path, encoding='utf-8')
print('Successfully written output file at {}'.format(output_path))
# Out:
# Successfully written output file at output/us_cities.gpkg

# %% [markdown]
# ----
