# %% [markdown]
# A simple example showing how to extract data from web pages using Pandas.

# %%
import pandas as pd

# %%
results = pd.read_html('https://lgdirectory.gov.in/')
print(len(results))
# Out:
# 3

# %%
df1 = results[0]
df1
# Out:
#     S.No.                                 State/UT Name  No. of Districts  \
# 0     1.0                   ANDAMAN AND NICOBAR ISLANDS                 3
# 1     2.0                                ANDHRA PRADESH                26
# 2     3.0                             ARUNACHAL PRADESH                25
# 3     4.0                                         ASSAM                35
# 4     5.0                                         BIHAR                38
# 5     6.0                                    CHANDIGARH                 1
# 6     7.0                                  CHHATTISGARH                33
# 7     8.0                                         DELHI                11
# 8     9.0                                           GOA                 2
# 9    10.0                                       GUJARAT                33
# 10   11.0                                       HARYANA                22
# 11   12.0                              HIMACHAL PRADESH                12
# ...
